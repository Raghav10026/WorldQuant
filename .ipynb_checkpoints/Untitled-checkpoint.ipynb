# %%
import pandas as pd
import numpy as np

# %%
res = pd.read_csv('simulate_result_rename.csv')

# %%
res = res.dropna(how='all')

# %%
res.tail()
# Out:
#                             alpha       year  long_count  short_count     pnl  \
# 12812  ppent / inventory_turnover       2014       534.0       1176.0    115K
# 12813  ppent / inventory_turnover       2015       530.0       1159.0    661K
# 12814  ppent / inventory_turnover       2016       529.0       1176.0   -696K
# 12815  ppent / inventory_turnover       2017       533.0       1158.0   48.2K
# 12816  ppent / inventory_turnover  2012-2017       538.0       1195.0  -1.43M
#
#        sharpe  fitness returns draw_down turn_over     margin
# 12812    0.14     0.08   1.15%     3.12%     3.90%    5.85bpm
# 12813    1.01     1.29   6.61%     2.45%     4.04%   32.43bpm
# 12814   -1.07    -1.50  -6.96%     5.21%     3.53%  -39.10bpm
# 12815    0.67     0.84   3.57%     0.64%     2.29%   31.01bpm
# 12816   -0.41    -0.35  -2.91%    11.50%     3.98%  -14.52bpm

# %%
res.shape
# Out:
# (12803, 11)

# %%
index = list(res.index)

# %%
index = list(res.index)
for i in range(len(index))[:-1]:
    if index[i] + 1 != index[i + 1]:
        print (i + 1) / 7, i
# Out:
# 1541 10786
# 1792 12543

# %%
res.iloc[10786:10790]
# Out:
#                      alpha       year  long_count  short_count     pnl  \
# 10786  rd_expense / equity  2012-2017       978.0        878.0   -289K
# 10794  receivable / equity       2012      1017.0       1567.0  -56.2K
# 10795  receivable / equity       2013      1045.0       1537.0   1.82M
# 10796  receivable / equity       2014      1005.0       1566.0   -885K
#
#        sharpe  fitness returns draw_down turn_over     margin
# 10786   -0.03    -0.01  -0.59%    24.93%    10.56%   -1.10bpm
# 10794   -0.14    -0.06  -0.71%     2.90%     4.14%   -3.39bpm
# 10795    2.74     5.34  18.15%     1.57%     4.77%   75.50bpm
# 10796   -0.99    -1.35  -8.85%     7.78%     4.75%  -36.98bpm

# %%
mask = res.fitness < -1.5
res[mask]
# Out:
#                                      alpha       year  long_count  \
# 146                 current_ratio / assets  2012-2017       664.0
# 776            current_ratio / assets_curr  2012-2017       691.0
# 1077       assets_curr / operating_expense  2012-2017       814.0
# 1105                   assets_curr / ppent  2012-2017       696.0
# 1343           bookvalue_ps / cashflow_fin  2012-2017      1340.0
# 2064                          EBIT / capex  2012-2017      1070.0
# 2078                        EBITDA / capex  2012-2017      1056.0
# 2127                           capex / eps  2012-2017       952.0
# 2190                    income_tax / capex  2012-2017      1013.0
# 2330                 pretax_income / capex  2012-2017      1140.0
# 2883              cash / operating_expense  2012-2017       738.0
# 2911                          cash / ppent  2012-2017       648.0
# 3674   cashflow_invst / cashflow_dividends  2012-2017       973.0
# ...

# %%
df1 = pd.read_csv('result_2.csv')
df2 = pd.read_csv('result_3.csv')
df3 = pd.read_csv('result_4.csv')

# %%
df1 = df1.dropna(how='all')
df1.head()
# Out:
#                   alpha  year  long_count  short_count    pnl  sharpe  \
# 0  assets_curr / assets  2012      1006.0       1118.0  -460K   -1.77
# 1  assets_curr / assets  2013      1000.0       1119.0   407K    1.16
# 2  assets_curr / assets  2014       999.0       1117.0  -107K   -0.18
# 3  assets_curr / assets  2015       983.0       1089.0   118K    0.22
# 4  assets_curr / assets  2016       982.0       1059.0  -257K   -0.52
#
#    fitness returns draw_down turn_over     margin
# 0    -2.40  -5.71%     2.96%     3.10%  -36.52bpm
# 1     1.57   4.07%     2.21%     2.23%   36.17bpm
# 2    -0.12  -1.07%     4.89%     2.42%   -8.76bpm
# 3     0.15   1.18%     2.77%     2.72%    8.63bpm
# 4    -0.56  -2.57%     3.07%     2.24%  -22.73bpm

# %%
df1.tail()
# Out:
#                                  alpha       year  long_count  short_count  \
# 1682  operating_expense / bookvalue_ps       2014       903.0       1630.0
# 1683  operating_expense / bookvalue_ps       2015       846.0       1683.0
# 1684  operating_expense / bookvalue_ps       2016       871.0       1692.0
# 1685  operating_expense / bookvalue_ps       2017       884.0       1710.0
# 1686  operating_expense / bookvalue_ps  2012-2017       875.0       1683.0
#
#         pnl  sharpe  fitness returns draw_down turn_over     margin
# 1682  -758K   -0.84    -1.14  -7.58%     6.46%     4.11%  -36.61bpm
# 1683  1.09M    1.20     1.94  10.93%     2.19%     4.22%   51.43bpm
# 1684  -468K   -0.92    -1.15  -4.68%     3.01%     3.01%  -30.84bpm
# 1685   169K    2.75     7.37  14.65%     0.43%     2.05%  142.02bpm
# 1686  1.32M    0.30     0.26   2.69%     6.46%     3.58%   14.91bpm

# %%
df2 = df2.dropna(how='all')
df2.head()
# Out:
#                                  alpha  year  long_count  short_count     pnl  \
# 1687  bookvalue_ps / operating_expense  2012       932.0       1671.0   -122K
# 1688  bookvalue_ps / operating_expense  2013       986.0       1578.0   -133K
# 1689  bookvalue_ps / operating_expense  2014       996.0       1536.0  -1.03M
# 1690  bookvalue_ps / operating_expense  2015      1007.0       1522.0    144K
# 1691  bookvalue_ps / operating_expense  2016       996.0       1566.0   3.34M
#
#       sharpe  fitness  returns draw_down turn_over     margin
# 1687   -0.14    -0.08   -1.51%     3.47%     5.00%   -6.00bpm
# 1688   -0.06    -0.03   -1.33%    10.00%     6.93%   -3.80bpm
# 1689   -0.64    -0.75  -10.31%     9.73%     7.46%  -27.42bpm
# 1690    0.12     0.05    1.44%     5.27%     6.95%    4.10bpm
# 1691    1.96     5.40   33.37%     8.35%     4.39%  150.68bpm

# %%
df2.tail()
# Out:
#                        alpha       year  long_count  short_count    pnl  \
# 5462  goodwill / cashflow_op       2014       904.0       1464.0  -624K
# 5463  goodwill / cashflow_op       2015       854.0       1515.0   132K
# 5464  goodwill / cashflow_op       2016       852.0       1530.0  -475K
# 5465  goodwill / cashflow_op       2017       858.0       1530.0   175K
# 5466  goodwill / cashflow_op  2012-2017       883.0       1490.0  -809K
#
#       sharpe  fitness returns draw_down turn_over     margin
# 5462   -0.83    -0.98  -6.24%     4.13%     4.52%  -27.41bpm
# 5463    0.21     0.12   1.32%     2.70%     4.36%    6.00bpm
# 5464   -0.61    -0.68  -4.75%     4.94%     3.72%  -25.30bpm
# 5465    2.18     5.72  14.66%     0.95%     2.13%  136.58bpm
# 5466   -0.22    -0.14  -1.64%    11.09%     4.16%   -7.82bpm

# %%
df3.dropna(how='all').tail()
# Out:
#                  alpha       year  long_count  short_count     pnl  sharpe  \
# 9662  ppent / employee       2014       848.0       1429.0   2.00M    2.58
# 9663  ppent / employee       2015       827.0       1448.0   -172K   -0.18
# 9664  ppent / employee       2016       844.0       1436.0  -1.64M   -1.61
# 9665  ppent / employee       2017       846.0       1440.0  -89.2K   -0.72
# 9666  ppent / employee  2012-2017       851.0       1442.0    349K    0.08
#
#       fitness  returns draw_down turn_over      margin
# 9662     6.57   20.04%     2.25%     3.08%   129.05bpm
# 9663    -0.12   -1.72%     3.59%     3.93%    -8.71bpm
# 9664    -4.09  -16.36%     8.25%     2.54%  -127.80bpm
# 9665    -1.47   -7.25%     1.04%     1.74%   -82.65bpm
# 9666     0.04    0.71%    12.35%     3.21%     4.38bpm

# %%
df = pd.concat([df1, df2, df3])

# %%
df.iloc[2380:2390]
# Out:
#                       alpha       year  long_count  short_count     pnl  \
# 2380  return_assets / capex       2012      1013.0       1455.0   5.03M
# 2381  return_assets / capex       2013      1080.0       1349.0  -2.32M
# 2382  return_assets / capex       2014      1122.0       1290.0  -3.35M
# 2383  return_assets / capex       2015      1098.0       1296.0   -943K
# 2384  return_assets / capex       2016      1090.0       1317.0  -1.18M
# 2385  return_assets / capex       2017      1093.0       1306.0   97.2K
# 2386  return_assets / capex  2012-2017      1083.0       1336.0  -2.66M
# 2394  return_equity / capex       2012      1075.0       1373.0   1.47M
# 2395  return_equity / capex       2013      1129.0       1283.0  -3.81M
# 2396  return_equity / capex       2014      1071.0       1323.0  -4.27M
#
#       sharpe  fitness  returns draw_down turn_over      margin
# 2380    2.64     8.17   62.48%     8.77%     6.51%   190.47bpm
# ...

# %%
alp = pd.read_csv('alphas_for_simulate.csv')

# %%
alp.iloc[1410]
# Out:
# alpha    goodwill / enterprise_value
# Name: 1410, dtype: object

# %%
res_df = pd.DataFrame(index=range(alp.shape[0] * 7), columns=['alpha', 'year', 'long_count', 'short_count', 'pnl', 'sharpe', 'fitness', 
               'returns', 'draw_down', 'turn_over', 'margin'])

# %%
res_df.shape
# Out:
# (15134, 11)

# %%
res_df.iloc[0:1687] = df1.iloc[0:1687]

# %%
res_df.iloc[1687:5467] = df2.iloc[1687:5467]

# %%
res_df.iloc[5467:9667] = df3.iloc[5467:9667]

# %%
res_df.iloc[2380:2400]
# Out:
#                       alpha       year long_count short_count     pnl sharpe  \
# 2380  return_assets / capex       2012       1013        1455   5.03M   2.64
# 2381  return_assets / capex       2013       1080        1349  -2.32M   -0.8
# 2382  return_assets / capex       2014       1122        1290  -3.35M   -1.3
# 2383  return_assets / capex       2015       1098        1296   -943K  -0.47
# 2384  return_assets / capex       2016       1090        1317  -1.18M  -0.54
# 2385  return_assets / capex       2017       1093        1306   97.2K   0.33
# 2386  return_assets / capex  2012-2017       1083        1336  -2.66M  -0.22
# 2387                    NaN        NaN        NaN         NaN     NaN    NaN
# 2388                    NaN        NaN        NaN         NaN     NaN    NaN
# 2389                    NaN        NaN        NaN         NaN     NaN    NaN
# 2390                    NaN        NaN        NaN         NaN     NaN    NaN
# ...

# %%
res_df.to_csv('simulate_result_rename.csv', index=False)

# %%
d = pd.read_csv('simulate_result_rename.csv')
d.head()
# Out:
#                   alpha  year  long_count  short_count    pnl  sharpe  \
# 0  assets_curr / assets  2012      1006.0       1118.0  -460K   -1.77
# 1  assets_curr / assets  2013      1000.0       1119.0   407K    1.16
# 2  assets_curr / assets  2014       999.0       1117.0  -107K   -0.18
# 3  assets_curr / assets  2015       983.0       1089.0   118K    0.22
# 4  assets_curr / assets  2016       982.0       1059.0  -257K   -0.52
#
#    fitness returns draw_down turn_over     margin
# 0    -2.40  -5.71%     2.96%     3.10%  -36.52bpm
# 1     1.57   4.07%     2.21%     2.23%   36.17bpm
# 2    -0.12  -1.07%     4.89%     2.42%   -8.76bpm
# 3     0.15   1.18%     2.77%     2.72%    8.63bpm
# 4    -0.56  -2.57%     3.07%     2.24%  -22.73bpm

# %%
d.dropna(how='all').tail()
# Out:
#                             alpha       year  long_count  short_count     pnl  \
# 9872  goodwill / enterprise_value       2014       675.0       1121.0    433K
# 9873  goodwill / enterprise_value       2015       673.0       1095.0  -1.56M
# 9874  goodwill / enterprise_value       2016       675.0       1080.0    519K
# 9875  goodwill / enterprise_value       2017       678.0       1081.0    313K
# 9876  goodwill / enterprise_value  2012-2017       674.0       1104.0   -596K
#
#       sharpe  fitness  returns draw_down turn_over     margin
# 9872    0.69     0.44    4.33%     2.50%    10.34%    8.30bpm
# 9873   -2.26    -2.93  -15.60%     9.91%     9.30%  -33.26bpm
# 9874    0.65     0.41    5.19%     2.92%    12.95%    7.95bpm
# 9875    3.49     8.90   24.65%     0.33%     3.78%  129.26bpm
# 9876   -0.14    -0.04   -1.21%    10.92%    11.88%   -2.02bpm

# %%
res_df.dropna(how='all').tail()
# Out:
#                  alpha       year long_count short_count     pnl sharpe  \
# 9662  ppent / employee       2014        848        1429   2.00M   2.58
# 9663  ppent / employee       2015        827        1448   -172K  -0.18
# 9664  ppent / employee       2016        844        1436  -1.64M  -1.61
# 9665  ppent / employee       2017        846        1440  -89.2K  -0.72
# 9666  ppent / employee  2012-2017        851        1442    349K   0.08
#
#      fitness  returns draw_down turn_over      margin
# 9662    6.57   20.04%     2.25%     3.08%   129.05bpm
# 9663   -0.12   -1.72%     3.59%     3.93%    -8.71bpm
# 9664   -4.09  -16.36%     8.25%     2.54%  -127.80bpm
# 9665   -1.47   -7.25%     1.04%     1.74%   -82.65bpm
# 9666    0.04    0.71%    12.35%     3.21%     4.38bpm

# %%
alp.iloc[1380]
# Out:
# alpha    ppent / employee
# Name: 1380, dtype: object
